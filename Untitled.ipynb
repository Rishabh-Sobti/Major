# %%
import seaborn as sns
import csv
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]
data = list(csv.reader(open('final_dataset.csv')))
states = list(set([row[0] for row in data]))
parties = list(set([row[1] for row in data]))
import numpy as np
corr = np.zeros((len(states), len(parties)))
for row in data:
    i=0
    j=0
    for k in range(len(states)):
        if(row[0]==states[k]):
            i=k
            break
    for l in range(len(parties)):
        if(row[1]==parties[l]):
            j=l
            break
    corr[i][j]=float(row[2])/float(row[6])
import pandas as pd
corr = pd.DataFrame(corr, states, parties)
fig, ax = plt.subplots()
ax = sns.heatmap(corr)
plt.show()

# %%
import numpy as np
y_true = np.array([3,23,2,10,0,2,1,0,5,3,3,0,16,12,18,52,0,1,2,1,303,1])
y_pred = np.array([7,5,0,59,1,2,8,0,9,14,1,0,4,6,5,174,1,0,3,2,236,7])

# %%
from sklearn.preprocessing import StandardScaler as MMX
a = MMX()
y_true = a.fit_transform(y_true.reshape(-1,1))
b = MMX()
y_pred = b.fit_transform(y_pred.reshape(-1,1))
# Out:
# /home/rishabh/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/rishabh/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/rishabh/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/rishabh/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
y_pred=y_pred/544.0

# %%
y_true=y_true/458.0

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2_score(y_true, y_pred)
# Out:
# 0.7287096225002352

# %%
mean_squared_error(y_true, y_pred)
# Out:
# 0.27129037749976487

# %%
mean_absolute_error(y_true, y_pred)
# Out:
# 0.26702851065724126
